# %% [markdown]
# # This script uses a Neural Network to predict EF Rating given Length (miles), Width (yds), Loss ($)

# %%
# !pip3 install ann_visualizer
# !pip install graphviz
# Out:
# Collecting ann_visualizer
#   Downloading ann_visualizer-2.5.tar.gz (4.7 kB)
# Building wheels for collected packages: ann-visualizer
#   Building wheel for ann-visualizer (setup.py) ... done
#   Created wheel for ann-visualizer: filename=ann_visualizer-2.5-py3-none-any.whl size=4168 sha256=68cb4101dc83afadef62521c1924d72c1382176a24ff7248e2cf7047099e5957
#   Stored in directory: /root/.cache/pip/wheels/1b/fc/58/2ab1c3b30350105929308becddda4fb59b1358e54f985e1f4a
# Successfully built ann-visualizer
# Installing collected packages: ann-visualizer
# Successfully installed ann-visualizer-2.5
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (0.10.1)

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# ### 1. Import & Inspect the Data

# %%
# # Connect to Google Drive
# from google.colab import drive 
# drive.mount('/content/gdrive')

# %%
# # Loading data
# tornado_df = pd.read_csv("gdrive/My Drive/Colab Notebooks/Final_Project/2008-2020_tornadoes_EF_cleaned.csv")
# tornado_df

# %%
# Apache Spark Set Up

import os
# Find the latest version of spark 3.0 from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.3'
spark_version = 'spark-3.2.1'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [770 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:13 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [85.2 kB]
# Get:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,957 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,762 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,004 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [932 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,503 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,197 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,277 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [966 kB]
# Get:24 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:25 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [44.3 kB]
# Fetched 15.9 MB in 6s (2,543 kB/s)
# Reading package lists... Done

# %%
# Start Spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Tornadoes").getOrCreate()

# %%
# Read in data from S3 Buckets
from pyspark import SparkFiles
url ="https://group-2-project-tornadoes.s3.amazonaws.com/2008-2020_tornadoes_EF_cleaned_db.csv"
spark.sparkContext.addFile(url)
tornado = spark.read.csv(SparkFiles.get("2008-2020_tornadoes_EF_cleaned_db.csv"), sep=",", header=True)

# Show DataFrame
tornado.show()
# Out:
# +-------+---------+----+-----+---+----------------+-------+---------+---------+---------+-------+-------+---+--------+----------+-------+---------+------+-----+
# |Torn_ID|County_ID|Year|Month|Day|       Timestamp|ST_FIPS|CNTY_FIPS|Start_Lat|Start_Lon|End_Lat|End_Lon| EF|Injuries|Fatalities|   Loss|Crop_Loss|Length|Width|
# +-------+---------+----+-----+---+----------------+-------+---------+---------+---------+-------+-------+---+--------+----------+-------+---------+------+-----+
# |      1|    35049|2008|   10| 11|10/11/2008 18:33|     35|       49|    35.15|  -105.94|      0|      0|  0|       0|         0|  12000|     null|  0.02|   10|
# |      2|    20181|2008|   10| 11|10/11/2008 21:54|     20|      181|    39.33|  -101.55|      0|      0|  0|       0|         0|   null|     null|  0.25|   10|
# |      3|    13039|2008|   10| 24|10/24/2008 16:55|     13|       39|    31.02|   -81.81|      0|      0|  0|       0|         0|   1000|     null|  0.25|   25|
# |      4|     5113|2008|   10|  6| 10/6/2008 13:46|      5|      113|    34.58|   -94.15|  34.63| -94.12|  1|       0|         0|  75000|     null|  3.41|  250|
# |      5|    48067|2008|   10|  6| 10/6/2008 16:05|     48|       67|    33.07|    -94.1|  33.09| -94.08|  0|       0|         0|  75000|     null|   1.5|  100|
# |      6|    48001|2008|   10|  6| 10/6/2008 19:29|     48|        1|    31.85|   -95.87|  31.88| -95.73|  0|       0|         0|  55000|     null|  6.95|   50|
# |      7|    48073|2008|   10|  6| 10/6/2008 21:10|     48|       73|    32.14|   -95.31|  32.14| -95.31|  0|       0|         0|   null|     null|   0.5|   50|
# 15890   15891     39041  2020     9   7    9/7/2020 15:14      39        41
#
#       Start_Lat Start_Lon  End_Lat    End_Lon EF Injuries Fatalities     Loss  \
# 0         35.15   -105.94        0          0  0        0          0    12000
# 1         39.33   -101.55        0          0  0        0          0     None
# 2         31.02    -81.81        0          0  0        0          0     1000
# 3         34.58    -94.15    34.63     -94.12  1        0          0    75000
# 4         33.07     -94.1    33.09     -94.08  0        0          0    75000
# ...         ...       ...      ...        ... ..      ...        ...      ...
# 15886    36.329  -89.4981  36.3517   -89.4729  0        0          0     None
# 15887    38.948  -76.5695  38.9233   -76.4615  0        0          0  1250000
# 15888     37.35   -119.34  37.5218  -119.3056  2        0          0     None
# 15889     37.25    -119.2  37.2598  -119.1838  1        0          0     None
# 15890   40.2966  -82.9889  40.2703   -82.9386  0        0          0    25000
#
#       Crop_Loss Length Width
# 0          None   0.02    10
# 1          None   0.25    10
# 2          None   0.25    25
# 3          None   3.41   250
# 4          None    1.5   100
# ...         ...    ...   ...
# 15886      2000    2.1    50
# 15887      None   6.05   100
# 15888      None  12.02    50
# 15889      None   1.12    25
# 15890      None   3.21   150
#
# [15891 rows x 19 columns]

# %%
# Check data types
tornado_df.dtypes
# Out:
# Torn_ID       object
# County_ID     object
# Year          object
# Month         object
# Day           object
# Timestamp     object
# ST_FIPS       object
# CNTY_FIPS     object
# Start_Lat     object
# Start_Lon     object
# End_Lat       object
# End_Lon       object
# EF            object
# Injuries      object
# Fatalities    object
# Loss          object
# Crop_Loss     object
# Length        object
# Width         object
# dtype: object

# %%
# Convert timestamp to datetime
tornado_df['Timestamp']= pd.to_datetime(tornado_df['Timestamp'])

# Convert all strings to numeric
cols=[i for i in tornado_df.columns if i not in ["Timestamp"]]
for col in cols:
    tornado_df[col]=pd.to_numeric(tornado_df[col])

# check dtypes
tornado_df.dtypes
# Out:
# Torn_ID                int64
# County_ID              int64
# Year                   int64
# Month                  int64
# Day                    int64
# Timestamp     datetime64[ns]
# ST_FIPS                int64
# CNTY_FIPS              int64
# Start_Lat            float64
# Start_Lon            float64
# End_Lat              float64
# End_Lon              float64
# EF                     int64
# Injuries               int64
# Fatalities             int64
# Loss                 float64
# Crop_Loss            float64
# Length               float64
# Width                  int64
# dtype: object

# %%
tornado_df.columns
# Out:
# Index(['Torn_ID', 'County_ID', 'Year', 'Month', 'Day', 'Timestamp', 'ST_FIPS',
#        'CNTY_FIPS', 'Start_Lat', 'Start_Lon', 'End_Lat', 'End_Lon', 'EF',
#        'Injuries', 'Fatalities', 'Loss', 'Crop_Loss', 'Length', 'Width'],
#       dtype='object')

# %%
# drop na rows
tornado_df = tornado_df.dropna()

# %% [markdown]
# ### 1. Define input data (X) and output data (y)

# %%
X = tornado_df.copy()
X = X.drop(['Torn_ID','County_ID','Year', 'Month', 'Day', 'Timestamp','ST_FIPS','CNTY_FIPS','Start_Lat','Start_Lon','End_Lat', 'End_Lon','Injuries','Fatalities','Crop_Loss','EF'], axis=1)
X
# Out:
#             Loss  Length  Width
# 22      510000.0    8.13    200
# 28      500000.0    4.09    150
# 29     1000000.0    8.19    100
# 73      350000.0   10.59    500
# 81       20000.0    3.14    250
# ...          ...     ...    ...
# 15764    20000.0    1.26     50
# 15785    35000.0    0.26     50
# 15786    45000.0    2.17    100
# 15838   150000.0    2.58    100
# 15844   225000.0    0.87    100
#
# [640 rows x 3 columns]

# %%
y = tornado_df["EF"].ravel()
y[:10]
# Out:
# array([1, 2, 3, 1, 1, 3, 3, 1, 1, 1])

# %% [markdown]
# ### 2. Splitting into Train and Test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state =78)

# %% [markdown]
# ### 3. Scale the input data (X)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### 4. Define Deep Learning Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

# Rule of Thumb:
#   1. Number of Layers: Start with two hidden layers (this does not include the last layer).
#   2. Number of nodes (size) of intermediate layers: a number from the geometric progression of 2, e.g., 4, 8, 16, 32, … . 
#      The first layer should be around half of the number of input data features. The next layer size as half of the previous.

number_input_features = len(X.columns)
hidden_nodes_layer1 = 4
hidden_nodes_layer2 = 2

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add( tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu") )

# Second hidden layer
nn.add( tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu") )

# Output layer
nn.add( tf.keras.layers.Dense(units=1, activation="sigmoid") )

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 16
#
#  dense_1 (Dense)             (None, 2)                 10
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5. Compile & Train the Model

# %%
# Import checkpoint dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
# Compile the model
nn.compile(loss="mean_squared_error", optimizer="adam", metrics=["accuracy"])

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    period = 5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,validation_split=0.33, epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 23ms/step - loss: 1.4955 - accuracy: 0.3178 - val_loss: 1.1122 - val_accuracy: 0.3774
# Epoch 2/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.4828 - accuracy: 0.3583 - val_loss: 1.1048 - val_accuracy: 0.4277
# Epoch 3/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.4736 - accuracy: 0.4081 - val_loss: 1.0976 - val_accuracy: 0.4654
# Epoch 4/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.4646 - accuracy: 0.4174 - val_loss: 1.0908 - val_accuracy: 0.4906
# Epoch 5/100
#  1/11 [=>............................] - ETA: 0s - loss: 1.3018 - accuracy: 0.4375
# Epoch 5: saving model to checkpoints/weights.05.hdf5
# 11/11 [==============================] - 0s 6ms/step - loss: 1.4560 - accuracy: 0.4050 - val_loss: 1.0843 - val_accuracy: 0.4717
# Epoch 6/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.4486 - accuracy: 0.4330 - val_loss: 1.0791 - val_accuracy: 0.4591
# Epoch 7/100
# 11/11 [==============================] - 0s 7ms/step - loss: 1.4428 - accuracy: 0.4393 - val_loss: 1.0743 - val_accuracy: 0.4654
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.4377 - accuracy: 0.4393 - val_loss: 1.0699 - val_accuracy: 0.4591
# Epoch 9/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.4312 - accuracy: 0.4393 - val_loss: 1.0665 - val_accuracy: 0.4591
# Epoch 10/100
#  1/11 [=>............................] - ETA: 0s - loss: 1.4698 - accuracy: 0.3750
# Epoch 10: saving model to checkpoints/weights.10.hdf5
# 11/11 [==============================] - 0s 6ms/step - loss: 1.4250 - accuracy: 0.4424 - val_loss: 1.0627 - val_accuracy: 0.4591
# Epoch 11/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.4191 - accuracy: 0.4424 - val_loss: 1.0594 - val_accuracy: 0.4654
# Epoch 12/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.4133 - accuracy: 0.4455 - val_loss: 1.0560 - val_accuracy: 0.4654
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.4082 - accuracy: 0.4455 - val_loss: 1.0531 - val_accuracy: 0.4654
# Epoch 14/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.4033 - accuracy: 0.4455 - val_loss: 1.0504 - val_accuracy: 0.4654
# Epoch 15/100
#  1/11 [=>............................] - ETA: 0s - loss: 1.5753 - accuracy: 0.4375
# Epoch 15: saving model to checkpoints/weights.15.hdf5
# 11/11 [==============================] - 0s 6ms/step - loss: 1.3985 - accuracy: 0.4455 - val_loss: 1.0474 - val_accuracy: 0.4654
# Epoch 16/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.3937 - accuracy: 0.4455 - val_loss: 1.0445 - val_accuracy: 0.4654
# Epoch 17/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.3890 - accuracy: 0.4455 - val_loss: 1.0419 - val_accuracy: 0.4654
# Epoch 18/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.
100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.2325 - accuracy: 0.4455 - val_loss: 0.9340 - val_accuracy: 0.4654
# Epoch 79/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2302 - accuracy: 0.4455 - val_loss: 0.9326 - val_accuracy: 0.4654
# Epoch 80/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.7982 - accuracy: 0.6250
# Epoch 80: saving model to checkpoints/weights.80.hdf5
# 11/11 [==============================] - 0s 6ms/step - loss: 1.2283 - accuracy: 0.4455 - val_loss: 0.9314 - val_accuracy: 0.4654
# Epoch 81/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.2266 - accuracy: 0.4455 - val_loss: 0.9302 - val_accuracy: 0.4654
# Epoch 82/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2248 - accuracy: 0.4455 - val_loss: 0.9290 - val_accuracy: 0.4654
# Epoch 83/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.2231 - accuracy: 0.4455 - val_loss: 0.9276 - val_accuracy: 0.4654
# Epoch 84/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2212 - accuracy: 0.4455 - val_loss: 0.9264 - val_accuracy: 0.4654
# Epoch 85/100
#  1/11 [=>............................] - ETA: 0s - loss: 1.4361 - accuracy: 0.3750
# Epoch 85: saving model to checkpoints/weights.85.hdf5
# 11/11 [==============================] - 0s 7ms/step - loss: 1.2195 - accuracy: 0.4455 - val_loss: 0.9252 - val_accuracy: 0.4654
# Epoch 86/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.2178 - accuracy: 0.4455 - val_loss: 0.9241 - val_accuracy: 0.4654
# Epoch 87/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.2161 - accuracy: 0.4455 - val_loss: 0.9230 - val_accuracy: 0.4654
# Epoch 88/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2146 - accuracy: 0.4455 - val_loss: 0.9218 - val_accuracy: 0.4654
# Epoch 89/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.2130 - accuracy: 0.4455 - val_loss: 0.9206 - val_accuracy: 0.4654
# Epoch 90/100
#  1/11 [=>............................] - ETA: 0s - loss: 1.3481 - accuracy: 0.4375
# Epoch 90: saving model to checkpoints/weights.90.hdf5
# 11/11 [==============================] - 0s 7ms/step - loss: 1.2112 - accuracy: 0.4455 - val_loss: 0.9194 - val_accuracy: 0.4654
# Epoch 91/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2096 - accuracy: 0.4455 - val_loss: 0.9184 - val_accuracy: 0.4654
# Epoch 92/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2079 - accuracy: 0.4455 - val_loss: 0.9171 - val_accuracy: 0.4654
# Epoch 93/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.2061 - accuracy: 0.4455 - val_loss: 0.9159 - val_accuracy: 0.4654
# Epoch 94/100
# 11/11 [==============================] - 0s 5ms/step - loss: 1.2042 - accuracy: 0.4455 - val_loss: 0.9145 - val_accuracy: 0.4654
# Epoch 95/100
#  1/11 [=>............................] - ETA: 0s - loss: 1.2958 - accuracy: 0.4062
# Epoch 95: saving model to checkpoints/weights.95.hdf5
# 11/11 [==============================] - 0s 7ms/step - loss: 1.2024 - accuracy: 0.4455 - val_loss: 0.9135 - val_accuracy: 0.4654
# Epoch 96/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.2010 - accuracy: 0.4455 - val_loss: 0.9125 - val_accuracy: 0.4654
# Epoch 97/100
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1994 - accuracy: 0.4455 - val_loss: 0.9114 - val_accuracy: 0.4654
# Epoch 98/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.1979 - accuracy: 0.4455 - val_loss: 0.9103 - val_accuracy: 0.4654
# Epoch 99/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.1962 - accuracy: 0.4455 - val_loss: 0.9091 - val_accuracy: 0.4654
# Epoch 100/100
#  1/11 [=>............................] - ETA: 0s - loss: 1.4883 - accuracy: 0.3438
# Epoch 100: saving model to checkpoints/weights.100.hdf5
# 11/11 [==============================] - 0s 7ms/step - loss: 1.1945 - accuracy: 0.4455 - val_loss: 0.9081 - val_accuracy: 0.4654

# %% [markdown]
# ### 6. Save the Model

# %%
nn.save("NN_predictEF.h5")

# %% [markdown]
# ### 7. Plot Model Performance

# %%
print(fit_model.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(fit_model.history['accuracy'])
plt.plot(fit_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(fit_model.history['loss'])
plt.plot(fit_model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Visualize the Neural Network
from ann_visualizer.visualize import ann_viz
ann_viz(nn,view=True, filename="NN_predictEF", title= "EF Neural Network")

# %% [markdown]
# ### 6. Model Accuracy

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 5/5 - 0s - loss: 0.9723 - accuracy: 0.5312 - 162ms/epoch - 32ms/step
# Loss: 0.9723170399665833, Accuracy: 0.53125
