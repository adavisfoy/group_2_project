# %%
# Import dependencies
import pandas as pd
from path import Path

# %%
# Read tornadoes csv into DataFrame
file_path = Path('Raw_Data/1950-2020_torn.csv')
tornadoes_df = pd.read_csv(file_path, index_col=0)
tornadoes_df.head(25)
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# surr_key                                                             ...
# 1         192  1950  10   1   10/1/1950  21:00:00   3  OK   40   23  ...
# 2         193  1950  10   9   10/9/1950   2:15:00   3  NC   37    9  ...
# 3         195  1950  11  20  11/20/1950   2:20:00   3  KY   21    1  ...
# 4         196  1950  11  20  11/20/1950   4:00:00   3  KY   21    2  ...
# 5         197  1950  11  20  11/20/1950   7:30:00   3  MS   28   14  ...
# 6         194  1950  11   4   11/4/1950  17:00:00   3  PA   42    5  ...
# 7         198  1950  12   2   12/2/1950  15:00:00   3  IL   17    7  ...
# 8         199  1950  12   2   12/2/1950  16:00:00   3  IL   17    8  ...
# 9         200  1950  12   2   12/2/1950  16:25:00   3  AR    5   12  ...
# 10        201  1950  12   2   12/2/1950  17:30:00   3  IL   17    9  ...
# 11          4  1950   1  13   1/13/1950   5:25:00   3  AR    5    1  ...
# ...

# %%
# Review data types for tornadoes dataframe
tornadoes_df.dtypes
# Out:
# om         int64
# yr         int64
# mo         int64
# dy         int64
# date      object
# time      object
# tz         int64
# st        object
# stf        int64
# stn        int64
# f          int64
# inj        int64
# fat        int64
# loss     float64
# closs    float64
# slat     float64
# slon     float64
# elat     float64
# elon     float64
# len      float64
# wid        int64
# ns         int64
# sn         int64
# sg         int64
# f1         int64
# f2         int64
# f3         int64
# f4         int64
# fc         int64
# dtype: object

# %%
# Read hail csv into DataFrame
file_path_2 = Path('Raw_Data/1955-2020_hail.csv')
hail_df = pd.read_csv(file_path_2, index_col=0)
hail_df.head(25)
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# surr_key                                                             ...
# 1         327  1955  10  16  10/16/1955  13:15:00   3  NJ   34    1  ...
# 2         328  1955  10  23  10/23/1955  18:00:00   3  MI   26    7  ...
# 3         329  1955  10  28  10/28/1955   6:30:00   3  AR    5   12  ...
# 4         330  1955  10  28  10/28/1955  16:45:00   3  AL    1    9  ...
# 5         326  1955  10   6   10/6/1955  12:00:00   3  IL   17    8  ...
# 6         331  1955  11  13  11/13/1955  16:00:00   3  KY   21    5  ...
# 7         332  1955  11  13  11/13/1955  19:20:00   3  MI   26    8  ...
# 8         333  1955  11  15  11/15/1955  15:00:00   3  MO   29   27  ...
# 9         334  1955  11  15  11/15/1955  16:00:00   3  IL   17    9  ...
# 10        335  1955  11  15  11/15/1955  16:00:00   3  IL   17   10  ...
# 11        336  1955  11  15  11/15/1955  16:30:00   3  IL   17   11  ...
# ...

# %%
# Review data types for hail dataframe - should be the same but double checking
hail_df.dtypes
# Out:
# om         int64
# yr         int64
# mo         int64
# dy         int64
# date      object
# time      object
# tz         int64
# st        object
# stf        int64
# stn        int64
# sz       float64
# inj        int64
# fat        int64
# loss     float64
# closs    float64
# slat     float64
# slon     float64
# elat     float64
# elon     float64
# len        int64
# wid        int64
# ns         int64
# sn         int64
# sg         int64
# f1         int64
# f2         int64
# f3         int64
# f4         int64
# dtype: object

# %%
# Read wind csv into DataFrame
file_path_3 = Path('Raw_Data/1955-2020_wind.csv')
wind_df = pd.read_csv(file_path_3, index_col=0)
wind_df.head(25)
# Out:
# C:\Users\Valerie\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  len  \
# surr_key                                                             ...
# 1         397  1955  10  12  10/12/1955  15:00:00   3  AR    5   24  ...    0
# 2         398  1955  10  18  10/18/1955   8:00:00   3  FL   12    9  ...    0
# 3         399  1955  10  23  10/23/1955  18:00:00   3  MI   26    9  ...    0
# 4         400  1955  10  23  10/23/1955  19:00:00   3  MI   26   10  ...    0
# 5         401  1955  10  23  10/23/1955  20:00:00   3  MI   26   11  ...    0
# 6         402  1955  10  24  10/24/1955  15:00:00   3  PA   42    9  ...    0
# 7         403  1955  10  28  10/28/1955  11:30:00   3  MS   28    7  ...    0
# ...

# %%
# Review data types for wind dataframe - should be the same but double checking
wind_df.dtypes
# Out:
# om         int64
# yr         int64
# mo         int64
# dy         int64
# date      object
# time      object
# tz         int64
# st        object
# stf        int64
# stn        int64
# mag        int64
# inj        int64
# fat        int64
# loss     float64
# closs    float64
# slat     float64
# slon     float64
# elat     float64
# elon     float64
# len        int64
# wid        int64
# ns         int64
# sn         int64
# sg         int64
# f1         int64
# f2         int64
# f3         int64
# f4         int64
# mt        object
# dtype: object

# %%
# Loading and reading in dataset
# data from https://www.kaggle.com/datasets/atinakarim/noaa-severe-storm-database?select=tornado_path.csv
file_path_4 = Path('Raw_Data/tornado_path.csv')
tornado_path_df = pd.read_csv(file_path_4, index_col=0)
tornado_path_df.head(25)
# Out:
#            storm_time time_zone_offset state_abbreviation state_name  \
# storm_date
# 6/7/2015      0:15:00           -06:00                 IA       Iowa
# 11/11/2015   14:00:00           -06:00                 IA       Iowa
# 9/21/2016    17:32:00           -06:00                 IA       Iowa
# 5/1/2008     17:59:00           -06:00                 IA       Iowa
# 6/28/2017    16:05:00           -06:00                 IA       Iowa
# 4/13/2006    19:29:00           -06:00                 IA       Iowa
# 11/12/2005   16:58:00           -06:00                 IA       Iowa
# 6/1/2001     15:55:00           -06:00                 IA       Iowa
# 5/21/2004    17:08:00           -06:00                 IA       Iowa
# 3/6/2017     21:50:00           -06:00                 IA       Iowa
# 10/2/2007    15:40:00           -06:00                 IA       Iowa
# 6/16/2014    18:45:00           -06:00                 IA       Iowa
# ...

# %%
# Checking data types
tornado_path_df.dtypes
# Out:
# storm_time               object
# time_zone_offset         object
# state_abbreviation       object
# state_name               object
# state_fips_code           int64
# magnitude                object
# injured_count             int64
# fatality_count            int64
# property_loss           float64
# crop_loss               float64
# yearly_tornado_count      int64
# start_lon               float64
# start_lat               float64
# end_long                float64
# end_lat                 float64
# length                  float64
# width                     int64
# tornado_path_geom        object
# dtype: object

# %%
# Crop loss totals by state
Total_Tornadoes_by_State = tornado_path_df.groupby(["state_name"]).count()["yearly_tornado_count"]
Total_Tornadoes_by_State
# Out:
# state_name
# Alabama            805
# Alaska               3
# Arizona            140
# Arkansas           219
# California          26
# Colorado            37
# Connecticut         12
# Florida           1126
# Georgia            495
# Hawaii              24
# Idaho              110
# Illinois           213
# Indiana            538
# Iowa               935
# Kansas            2711
# Kentucky           224
# Louisiana          227
# Maine               56
# Maryland            47
# Massachusetts       10
# Michigan           103
# Minnesota           92
# Mississippi        451
# Missouri           227
# Montana            170
# Nebraska           149
# Nevada              71
# New Hampshire        2
# New Jersey           9
# New Mexico          11
# New York            48
# North Carolina     176
# North Dakota        57
# Ohio               297
# Oklahoma           272
# Oregon              55
# Pennsylvania       100
# Puerto Rico          4
# Rhode Island         1
# ...
